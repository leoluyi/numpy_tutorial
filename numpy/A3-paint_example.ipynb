# %%
from urllib.request import urlopen
from matplotlib import pyplot as plt
from matplotlib.pyplot import imread, imshow
from PIL import Image
# %matplotlib inline

# %%
p = urlopen('https://demo.presscustomizr.com/wp-content/uploads/2008/06/Jellyfish.jpg')
a = np.array(Image.open(p))

# %%
a.shape
# Out:
# (768, 1024, 3)

# %%
a[100,100]
# Out:
# array([  2,  38, 122], dtype=uint8)

# %%
a[100,100,0]
# Out:
# 2

# %%
imshow(a);

# %%
imshow(255-a);

# %%
imshow(a[100:600:,::, ::]); # 切範圍

# %%
b = np.zeros_like(a)

# %%
b[100:500, 200:400]=255

# %%
imshow(b)

# %%
b[700:750,700:750, 2] = 44
print(b[700:750,700:750])
# Out:
# [[[ 0  0 44]
#   [ 0  0 44]
#   [ 0  0 44]
#   ...,
#   [ 0  0 44]
#   [ 0  0 44]
#   [ 0  0 44]]
#
#  [[ 0  0 44]
#   [ 0  0 44]
#   [ 0  0 44]
#   ...,
#   [ 0  0 44]
#   [ 0  0 44]
#   [ 0  0 44]]
#
#  [[ 0  0 44]
#   [ 0  0 44]
#   [ 0  0 44]
#   ...,
#   [ 0  0 44]
#   [ 0  0 44]
#   [ 0  0 44]]
#
#  ...,
#  [[ 0  0 44]
#   [ 0  0 44]
#   [ 0  0 44]
#   ...,
#   [ 0  0 44]
#   [ 0  0 44]
#   [ 0  0 44]]
#
#  [[ 0  0 44]
#   [ 0  0 44]
#   [ 0  0 44]
#   ...,
#   [ 0  0 44]
#   [ 0  0 44]
#   [ 0  0 44]]
#
#  [[ 0  0 44]
#   [ 0  0 44]
#   [ 0  0 44]
#   ...,
#   [ 0  0 44]
#   [ 0  0 44]
#   [ 0  0 44]]]

# %%
b[700:750, 0:100] = [255, 0 , 255]
b[700:750]
# Out:
# array([[[255,   0, 255],
#         [255,   0, 255],
#         [255,   0, 255],
#         ...,
#         [  0,   0,   0],
#         [  0,   0,   0],
#         [  0,   0,   0]],
#
#        [[255,   0, 255],
#         [255,   0, 255],
#         [255,   0, 255],
#         ...,
#         [  0,   0,   0],
#         [  0,   0,   0],
#         [  0,   0,   0]],
#
#        [[255,   0, 255],
#         [255,   0, 255],
#         [255,   0, 255],
#         ...,
#         [  0,   0,   0],
#         [  0,   0,   0],
#         [  0,   0,   0]],
#
#        ...,
#        [[255,   0, 255],
#         [255,   0, 255],
#         [255,   0, 255],
#         ...,
#         [  0,   0,   0],
#         [  0,   0,   0],
#         [  0,   0,   0]],
#
#        [[255,   0, 255],
#         [255,   0, 255],
#         [255,   0, 255],
#         ...,
#         [  0,   0,   0],
#         [  0,   0,   0],
#         [  0,   0,   0]],
#
#        [[255,   0, 255],
#         [255,   0, 255],
#         [255,   0, 255],
#         ...,
#         [  0,   0,   0],
#         [  0,   0,   0],
#         [  0,   0,   0]]], dtype=uint8)

# %%
a.shape
# Out:
# (768, 1024, 3)

# %%
imshow(a[300:500, 200:400]);

# %%
b[100:300, 400:600] = a[300:500, 200:400]

# %%
imshow(b);

# %%
imshow(a[::10, ::10]); # 縮小取樣

# %%
a[::4, ::4].shape
# Out:
# (192, 256, 3)

# %%
b[:192, :256] = a[::4, ::4]
imshow(b);

# %%
for y in range(b.shape[0]):
    for x in range(b.shape[1]):
        if 100**2 < (x-400)**2 + (y-400)**2 < 200**2:
            b[y,x] = [255,0,255]
imshow(b);

# %%
for y in range(b.shape[0]):
    for x in range(b.shape[1]):
        b[y,x] =[x%200,y%200, 128+120*sin((x+y)/200.)]
imshow(b);

# %%
for y in range(b.shape[0]):
    for x in range(b.shape[1]):
        R = 100+120*sin(sqrt((x-300)**2 + (y-400)**2)/300.)
        G = 100+120*sin(sqrt((x-400)**2 + (y-400)**2)/700.)
        B = 100+120*cos(sqrt((x-500)**2 + (y-400)**2)/400.)
        b[y,x] = [R,G,B]
imshow(b);

# %%
c_array = a.copy()
print(c_array.shape)
print(c_array[[0,1,2], [0]])
c_array[:,:,1] = 0 # 關掉綠色
imshow(c_array)
# Out:
# (768, 1024, 3)
# [[  0  35 125]
#  [  1  42 124]
#  [  0  40 128]]
